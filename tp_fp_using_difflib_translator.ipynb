# %%
# read the xcometN for community post edition
# Read the JSON file
import json

with open("output_all_spans_translator.json", "r", encoding="utf-8") as f:
    loaded_data_all_spans = json.load(f)

# %%
loaded_data_all_spans[1]
# Out:
# [{'text': ['traduction', 'automatique', '(TA)'],
#   'confidence': 0.3870907425880432,
#   'severity': 'major',
#   'start': 31,
#   'end': 59,
#   'check severity': ['minor', 'minor', 'major']},
#  {'text': ["l'accompagnement", "d'un", 'contexte'],
#   'confidence': 0.40466970205307007,
#   'severity': 'major',
#   'start': 120,
#   'end': 151,
#   'check severity': ['minor', 'major', 'minor']}]

# %%
loaded_data_all_spans[3]
# Out:
# [{'text': ['de', 'la', 'MT', 'multimodale'],
#   'confidence': 0.3663173317909241,
#   'severity': 'minor',
#   'start': 37,
#   'end': 58,
#   'check severity': ['minor', 'minor', 'minor', 'minor']},
#  {'text': ['MT', 'textuelle', 'solide,'],
#   'confidence': 0.38611459732055664,
#   'severity': 'major',
#   'start': 81,
#   'end': 102,
#   'check severity': ['minor', 'major', 'major', 'major']},
#  {'text': ['qui', 'est', 'entraîné'],
#   'confidence': 0.5078727602958679,
#   'severity': 'major',
#   'start': 191,
#   'end': 208,
#   'check severity': ['major', 'major', 'major', 'major', 'major']},
#  {'text': ['sur'],
#   'confidence': 0.41356953978538513,
#   'severity': 'major',
#   'start': 222,
#   'end': 226,
#   'check severity': ['major']},
#  {'text': ['masquage'],
#   'confidence': 0.36415594816207886,
#   'severity': 'major',
#   'start': 229,
#   'end': 238,
#   'check severity': ['major', 'major']},
#  {'text': ['multimodale.'],
#   'confidence': 0.33852776885032654,
#   'severity': 'major',
#   'start': 254,
#   'end': 267,
#   'check severity': ['major']}]

# %%
one_sentence_spans = loaded_data_all_spans[3]

# %%
one_sentence_spans
# Out:
# [{'text': ['de', 'la', 'MT', 'multimodale'],
#   'confidence': 0.3663173317909241,
#   'severity': 'minor',
#   'start': 37,
#   'end': 58,
#   'check severity': ['minor', 'minor', 'minor', 'minor']},
#  {'text': ['MT', 'textuelle', 'solide,'],
#   'confidence': 0.38611459732055664,
#   'severity': 'major',
#   'start': 81,
#   'end': 102,
#   'check severity': ['minor', 'major', 'major', 'major']},
#  {'text': ['qui', 'est', 'entraîné'],
#   'confidence': 0.5078727602958679,
#   'severity': 'major',
#   'start': 191,
#   'end': 208,
#   'check severity': ['major', 'major', 'major', 'major', 'major']},
#  {'text': ['sur'],
#   'confidence': 0.41356953978538513,
#   'severity': 'major',
#   'start': 222,
#   'end': 226,
#   'check severity': ['major']},
#  {'text': ['masquage'],
#   'confidence': 0.36415594816207886,
#   'severity': 'major',
#   'start': 229,
#   'end': 238,
#   'check severity': ['major', 'major']},
#  {'text': ['multimodale.'],
#   'confidence': 0.33852776885032654,
#   'severity': 'major',
#   'start': 254,
#   'end': 267,
#   'check severity': ['major']}]

# %%
all_spans_in_this_sentence = []
all_spans_in_this_sentence_severity = []
for span in one_sentence_spans:
    all_spans_in_this_sentence.extend(span['text'].copy())
    length_of_text = len(span['text'])
    print(length_of_text)
    all_spans_in_this_sentence_severity.extend([span['severity']] * length_of_text)
print(all_spans_in_this_sentence)
print(all_spans_in_this_sentence_severity)
len(all_spans_in_this_sentence_severity)
# Out:
# 4
# 3
# 3
# 1
# 1
# 1
# ['de', 'la', 'MT', 'multimodale', 'MT', 'textuelle', 'solide,', 'qui', 'est', 'entraîné', 'sur', 'masquage', 'multimodale.']
# ['minor', 'minor', 'minor', 'minor', 'major', 'major', 'major', 'major', 'major', 'major', 'major', 'major', 'major']
# 13

# %%
loaded_data_all_spans[108]
# Out:
# [{'text': ['normaliser', 'les', 'termes', 'multi-mots'],
#   'confidence': 0.3957681357860565,
#   'severity': 'major',
#   'start': 64,
#   'end': 97,
#   'check severity': ['minor',
#    'minor',
#    'minor',
#    'major',
#    'major',
#    'minor',
#    'major',
#    'major']},
#  {'text': ['ontologie'],
#   'confidence': 0.37188562750816345,
#   'severity': 'minor',
#   'start': 121,
#   'end': 131,
#   'check severity': ['minor']}]

# %%
loaded_data_all_spans[121]
# Out:
# [{'text': ['indices', 'd’amorçage'],
#   'confidence': 0.4179653227329254,
#   'severity': 'minor',
#   'start': 70,
#   'end': 89,
#   'check severity': ['minor', 'minor', 'minor', 'minor', 'minor']}]

# %%
with open("relevant_words_in_pet_translator_without_mapping.json", "r", encoding="utf-8") as f:
    relevant_words_community = json.load(f)

# %%
relevant_words_community[1]
# Out:
# []

# %%
print("total relevant words: ",sum(len(li) for li in relevant_words_community))
# Out:
# total relevant words:  2983

# %%
tp_community = 0
fp_community = 0
import copy

# %%
from difflib import SequenceMatcher
def return_opcode_results(index, words1, all_spans_in_this_sentence_severity,words2,severity_tp, severity_fp):
    matcher = SequenceMatcher(None, words1, words2)
    opcodes = matcher.get_opcodes()
    tp = 0
    fp = 0
    fn = 0
    #print("index: ", index, "opcodes", opcodes)
    #print(f"words1: {words1} and words2: {words2}")
    replace = 0
    print(f"words1: {words1}")
    print(f"words2: {words2}")
    print("opcodes: ", opcodes)
    print("it is ===============================")
    print("index is: ", index)
    
    for opcod in opcodes:
        if opcod[0] == "equal":
            tp += opcod[2] - opcod[1]
           
            all_severity = all_spans_in_this_sentence_severity[opcod[1]:opcod[2]].copy()
            for severity in all_severity:
                if severity in severity_tp:
                    severity_tp[severity] +=1
                else:
                    severity_tp[severity] =1
            print("current tp: ",  opcod[2] - opcod[1], "total tp: ", tp)
        elif opcod[0] == "delete":
            fp += opcod[2] - opcod[1]
            all_severity = all_spans_in_this_sentence_severity[opcod[1]:opcod[2]].copy()
            for severity in all_severity:
                if severity in severity_fp:
                    severity_fp[severity] +=1
                else:
                    severity_fp[severity] =1
        elif opcod[0] == "insert":
            fn += opcod[4]-opcod[3]
        else:
            replace += opcod[2] - opcod[1]
            fp += opcod[2] - opcod[1]
            all_severity = all_spans_in_this_sentence_severity[opcod[1]:opcod[2]].copy()
            for severity in all_severity:
                if severity in severity_fp:
                    severity_fp[severity] +=1
                else:
                    severity_fp[severity] =1
            fn += opcod[4] - opcod[3]
            # print("it is replaced===============================")
            
            # print(f"words1: {words1}")
            # print(f"words2: {words2}")
            # print("opcodes: ", opcodes)
        # else:
        #     fp += 
    return tp, fp, fn,replace

# %%
def calculate_tp_fp(all_spans, relevant_words):
    tp = 0
    fp = 0
    fn = 0
    replace = 0
    severity_tp = {}
    severity_fp = {}
    for index,each_sentence in enumerate(all_spans):
        all_spans_in_this_sentence = []
        all_spans_in_this_sentence_severity = []
        for span in each_sentence:
            all_spans_in_this_sentence.extend(span['text'].copy())
            length_of_text = len(span['text'])
            #print(length_of_text)
            all_spans_in_this_sentence_severity.extend([span['severity']] * length_of_text)
        tp_tmp, fp_tmp, fn_tmp, replace_tmp = return_opcode_results(index,all_spans_in_this_sentence,all_spans_in_this_sentence_severity, relevant_words[index],severity_tp,severity_fp)
        
        tp += tp_tmp
        fp += fp_tmp
        fn += fn_tmp
        replace += replace_tmp
        print("total tp global: ", tp)
    print("severity_tp: ", severity_tp)
    print("severity_fp: ", severity_fp)
    return tp, fp, fn, replace

# %%
tp, fp, fn, replace = calculate_tp_fp(loaded_data_all_spans, relevant_words_community)
# Out:
# words1: ['automatique']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  0
# total tp global:  0
# words1: ['traduction', 'automatique', '(TA)', "l'accompagnement", "d'un", 'contexte']
# words2: []
# opcodes:  [('delete', 0, 6, 0, 0)]
# it is ===============================
# index is:  1
# total tp global:  0
# words1: ['traduction', 'automatique']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  2
# total tp global:  0
# words1: ['de', 'la', 'MT', 'multimodale', 'MT', 'textuelle', 'solide,', 'qui', 'est', 'entraîné', 'sur', 'masquage', 'multimodale.']
# words2: []
# opcodes:  [('delete', 0, 13, 0, 0)]
# it is ===============================
# index is:  3
# total tp global:  0
# words1: ['multilingue', 'contrastive,']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  4
# total tp global:  0
# words1: ['textuels', 'forts', 'anglais-français', 'ensemble', 'de', 'tests', 'contrastifs.']
# words2: ['baselines', 'MMT']
# opcodes:  [('replace', 0, 7, 0, 2)]
# it is ===============================
# index is:  5
# total tp global:  0
# words1: ['Similarité', 'conceptuelle', 'pour', 'les', 'balises', 'subjectives']
# words2: ['balises', 'subjectives']
# opcodes:  [('delete', 0, 4, 0, 0), ('equal', 4, 6, 0, 2)]
# it is ===============================
# index is:  6
# current tp:  2 total tp:  2
# total tp global:  2
# words1: ['marquage']
# words2: ['Le', 'marquage', 'est']
# opcodes:  [('insert', 0, 0, 0, 1), ('equal', 0, 1, 1, 2), ('insert', 1, 1, 2, 3)]
# it is ===============================
# index is:  7
# current tp:  1 total tp:  1
# total tp global:  3
# words1: ['balises', 'facilitent', "l'extraction"]
# words2: ['Les', 'balises']
# opcodes:  [('insert', 0, 0, 0, 1), ('equal', 0, 1, 1, 2), ('delete', 1, 3, 2, 2)]
# it is ===============================
# index is:  8
# current tp:  1 total tp:  1
# total tp global:  4
# words1: ['similarité', 'cosinus,', "l'ambiance"]
# words2: ['étiquettes', 'étiquettes,']
# opcodes:  [('replace', 0, 3, 0, 2)]
# it is ===============================
# index is:  9
# total tp global:  4
# words1: ['étiquettes', 'subjectives', 'subjectifs']
# words2: ['étiquettes', 'subjectives']
# opcodes:  [('equal', 0, 2, 0, 2), ('delete', 2, 3, 2, 2)]
# it is ===============================
# index is:  10
# current tp:  2 total tp:  2
# total tp global:  6
# words1: ['une', 'similarité', 'conceptuelle', 'conscience', 'les', 'étiquettes.']
# words2: ['étiquettes.']
# opcodes:  [('delete', 0, 5, 0, 0), ('equal', 5, 6, 0, 1)]
# it is ===============================
# index is:  11
# current tp:  1 total tp:  1
# total tp global:  7
# words1: ['pipeline', 'et', 'rentable', 'former', 'le', 'modèle', 'de', 'similarité', 'conceptuelle.']
# words2: ['un']
# opcodes:  [('replace', 0, 9, 0, 1)]
# it is ===============================
# index is:  12
# total tp global:  7
# words1: ['aval.']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  13
# total tp global:  7
# words1: ['travail']
# words2: ['étiquettes', 'subjectives.']
# opcodes:  [('replace', 0, 1, 0, 2)]
# it is ===============================
# index is:  14
# total tp global:  7
# words1: ['Analyse', 'discriminante', 'du', 'noyau', 'incrémental', 'et', 'compressible']
# words2: []
# opcodes:  [('delete', 0, 7, 0, 0)]
# it is ===============================
# index is:  15
# total tp global:  7
# words1: ['L’analyse', 'discriminante', 'du', 'noyau', '(KDA),', 'apprendre', 'ensembles']
# words2: ['l’extension']
# opcodes:  [('replace', 0, 7, 0, 1)]
# it is ===============================
# index is:  16
# total tp global:  7
# words1: ['motifs']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  17
# total tp global:  7
# words1: ['matrice', 'du', 'noyau.']
# words2: ['critiques:', 'à']
# opcodes:  [('replace', 0, 3, 0, 2)]
# it is ===============================
# index is:  18
# total tp global:  7
# words1: ['de', 'technologie', 'rapportées', 'la', 'KDA', 'nulle,', 'résoudre', 'le', 'KDA', 'nul', '(NKDA)']
# words2: ['nul']
# opcodes:  [('delete', 0, 9, 0, 0), ('equal', 9, 10, 0, 1), ('delete', 10, 11, 1, 1)]
# it is ===============================
# index is:  19
# current tp:  1 total tp:  1
# total tp global:  8
# words1: []
# words2: ['points:']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  20
# total tp global:  8
# words1: ['suivante:', 'rger', 'la', 'taille', 'des', 'données', 'd’entraînement', 'plus', 'le', 'contrat', 'd’espace', 'nul']
# words2: ['rger', 'nul']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 2, 0, 1), ('delete', 2, 11, 1, 1), ('equal', 11, 12, 1, 2)]
# it is ===============================
# index is:  21
# current tp:  1 total tp:  1
# current tp:  1 total tp:  2
# total tp global:  10
# words1: ['l’espace', 'nul', 'indicateur', 'redondance', 'l’ensemble', 'de', 'données', 'd’entraînement.']
# words2: []
# opcodes:  [('delete', 0, 8, 0, 0)]
# it is ===============================
# index is:  22
# total tp global:  10
# words1: ['pierre', 'KNDA', 'incrémental']
# words2: ['KNDA']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 2, 0, 1), ('delete', 2, 3, 1, 1)]
# it is ===============================
# index is:  23
# current tp:  1 total tp:  1
# total tp global:  11
# words1: ['de', 'nouveauté', 'scénarios', 'multi-classes', 'd’une', 'classe']
# words2: []
# opcodes:  [('delete', 0, 6, 0, 0)]
# it is ===============================
# index is:  24
# total tp global:  11
# words1: ['l’espace', 'nul', 'seuils', 'nouveauté']
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  25
# total tp global:  11
# words1: ['des', 'classificateurs', 'de', 'pointe', 'applications', 'réelles', 'multi-classes', 'et', 'une', 'seule', 'classe.']
# words2: []
# opcodes:  [('delete', 0, 11, 0, 0)]
# it is ===============================
# index is:  26
# total tp global:  11
# words1: ['Corpora', 'parallèles', 'pour', 'le', 'domaine', 'biomédical']
# words2: ['Corpora']
# opcodes:  [('equal', 0, 1, 0, 1), ('delete', 1, 6, 1, 1)]
# it is ===============================
# index is:  27
# current tp:  1 total tp:  1
# total tp global:  12
# words1: []
# words2: ['sous', 'forme', 'de', 'de', 'pour', 'les']
# opcodes:  [('insert', 0, 0, 0, 6)]
# it is ===============================
# index is:  28
# total tp global:  12
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  29
# total tp global:  12
# words1: ['recherche']
# words2: ["d'informations", 'automatique', 'multilingues.']
# opcodes:  [('replace', 0, 1, 0, 3)]
# it is ===============================
# index is:  30
# total tp global:  12
# words1: ["l'étendue", 'couverture', 'des', 'corpus', 'parallèles', 'biomédical.']
# words2: []
# opcodes:  [('delete', 0, 6, 0, 0)]
# it is ===============================
# index is:  31
# total tp global:  12
# words1: ["(l'ensemble", 'EDP']
# words2: ['procédons', 'à', 'une', 'analyse', 'des', 'ensembles', 'données', 'pour', 'les']
# opcodes:  [('replace', 0, 2, 0, 9)]
# it is ===============================
# index is:  32
# total tp global:  12
# words1: ['corpus', 'tâche']
# words2: ['biomédicale.']
# opcodes:  [('replace', 0, 2, 0, 1)]
# it is ===============================
# index is:  33
# total tp global:  12
# words1: ['couverture', 'des']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  34
# total tp global:  12
# words1: ['Intégration', 'mémoires', 'traduction', 'automatique', 'non-autorégressive']
# words2: []
# opcodes:  [('delete', 0, 5, 0, 0)]
# it is ===============================
# index is:  35
# total tp global:  12
# words1: ['traduction', 'automatique', 'non', 'autorégressive', '(NAT)']
# words2: ['(NAT)']
# opcodes:  [('delete', 0, 4, 0, 0), ('equal', 4, 5, 0, 1)]
# it is ===============================
# index is:  36
# current tp:  1 total tp:  1
# total tp global:  13
# words1: ['NAT', 'l’édition,', 'Transformer', '(LevT),', 'mémoire', 'de', 'traduction', '(TM).']
# words2: ['(TM).']
# opcodes:  [('delete', 0, 7, 0, 0), ('equal', 7, 8, 0, 1)]
# it is ===============================
# index is:  37
# current tp:  1 total tp:  1
# total tp global:  14
# words1: ['scénario']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  38
# total tp global:  14
# words1: ['modèle', 'de', 'vanille', 'LevT', 'cadre.']
# words2: ['vanille']
# opcodes:  [('delete', 0, 2, 0, 0), ('equal', 2, 3, 0, 1), ('delete', 3, 5, 1, 1)]
# it is ===============================
# index is:  39
# current tp:  1 total tp:  1
# total tp global:  15
# words1: ['montrons', 'comment', 'former']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  40
# total tp global:  15
# words1: ['autorégressive,', 'charge', 'décodage.']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  41
# total tp global:  15
# words1: ['des', 'MT', 'dispenses', 'd’utiliser']
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  42
# total tp global:  15
# words1: ["L'Open", 'Access', 'Augmente-T-Il', 'Réellement', 'Son', 'Impact', '?', 'Analyse', 'Randomisée', 'À', 'Grande', 'Échelle']
# words2: ['Augmente-T-Il', 'Réellement', 'Son', 'Impact', 'Randomisée', 'À', 'Grande', 'Échelle']
# opcodes:  [('delete', 0, 2, 0, 0), ('equal', 2, 6, 0, 4), ('delete', 6, 8, 4, 4), ('equal', 8, 12, 4, 8)]
# it is ===============================
# index is:  43
# current tp:  4 total tp:  4
# current tp:  4 total tp:  8
# total tp global:  23
# words1: ["L'avantage", 'de', 'la', 'citation', 'libre', 'accès']
# words2: ['libre', 'accès', '(OACA)']
# opcodes:  [('delete', 0, 4, 0, 0), ('equal', 4, 6, 0, 2), ('insert', 6, 6, 2, 3)]
# it is ===============================
# index is:  44
# current tp:  2 total tp:  2
# total tp global:  25
# words1: ['témoin']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  45
# total tp global:  25
# words1: ['des', 'citations', '458', "l'arthrose", 'celui', '(MNCS', 'pondérés)', 'témoin', '(10', '310', '842).']
# words2: ['(MNCS', 'pondérés)', '(10', '310', '842).']
# opcodes:  [('delete', 0, 5, 0, 0), ('equal', 5, 7, 0, 2), ('delete', 7, 8, 2, 2), ('equal', 8, 11, 2, 5)]
# it is ===============================
# index is:  46
# current tp:  2 total tp:  2
# current tp:  3 total tp:  5
# total tp global:  30
# words1: ['sur', "l'arthrose", '024', '430)', 'témoin', '(#1', '533', '001),']
# words2: ['De', 'même,', 'nous', '(#1', '(#1', 'au', 'cours', 'de']
# opcodes:  [('replace', 0, 5, 0, 3), ('equal', 5, 6, 3, 4), ('replace', 6, 8, 4, 8)]
# it is ===============================
# index is:  47
# current tp:  1 total tp:  1
# total tp global:  31
# words1: ["d'OACA", 'entièrement', 'OA,', "qu'il", 'y', 'plutôt', 'désavantage.']
# words2: []
# opcodes:  [('delete', 0, 7, 0, 0)]
# it is ===============================
# index is:  48
# total tp global:  31
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  49
# total tp global:  31
# words1: ['Il', 'faut', "s'attendre", 'à', 'ce', "qu'il", "n'y", 'ait', 'pas', 'suffisamment', 'de', 'publications', 'du', 'BCAA', 'dans', 'les', 'revues', 'entièrement', 'consacrées', 'à', "l'arthrose,", 'créées', 'attrayantes', 'les', 'chercheurs', 'chevronnés', 'à', 'impact', 'élevé.']
# words2: []
# opcodes:  [('delete', 0, 29, 0, 0)]
# it is ===============================
# index is:  50
# total tp global:  31
# words1: ["L'avantage", 'de', 'citation']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  51
# total tp global:  31
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  52
# total tp global:  31
# words1: ['la', 'publication', 'OA']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  53
# total tp global:  31
# words1: ['Ecran', 'et', 'Détendez-vous:', 'Accélérer', 'de', 'Elastic-Net', 'identifiant', 'le', 'support', 'de', 'la', 'solution']
# words2: []
# opcodes:  [('delete', 0, 12, 0, 0)]
# it is ===============================
# index is:  54
# total tp global:  31
# words1: ['OK']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  55
# total tp global:  31
# words1: ['Modélisation', 'efficace', 'en', 'termes', 'de', 'données', 'CamemBERTa']
# words2: []
# opcodes:  [('delete', 0, 7, 0, 0)]
# it is ===============================
# index is:  56
# total tp global:  31
# words1: []
# words2: ['NLP']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  57
# total tp global:  31
# words1: ['calculs,']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  58
# total tp global:  31
# words1: ['DeBERTa', "l'objectif", 'de', 'formation', 'de']
# words2: []
# opcodes:  [('delete', 0, 5, 0, 0)]
# it is ===============================
# index is:  59
# total tp global:  31
# words1: ['en', 'aval', 'du', 'français,', 'de', 'partie', 'du', 'discours,', 'pointe']
# words2: ['de', 'la']
# opcodes:  [('delete', 0, 4, 0, 0), ('equal', 4, 5, 0, 1), ('replace', 5, 9, 1, 2)]
# it is ===============================
# index is:  60
# current tp:  1 total tp:  1
# total tp global:  32
# words1: ['jetons', 'MLM']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  61
# total tp global:  32
# words1: ['en', 'aval', 'Camem-BERT,', 'entraîné', 'nombre', 'de', 'tokens', "d'entrée."]
# words2: []
# opcodes:  [('delete', 0, 8, 0, 0)]
# it is ===============================
# index is:  62
# total tp global:  32
# words1: ['poids', 'et', "l'implémentation", 'du', 'code', 'de', 'CAMEMBERTA,', "l'article", 'objectif', "d'entraînement", 'DeBERTaV3.']
# words2: []
# opcodes:  [('delete', 0, 11, 0, 0)]
# it is ===============================
# index is:  63
# total tp global:  32
# words1: ['théories', 'de', 'conpiratie', 'la', 'COVID-19', 'transformateurs', 'd’intégration', 'de', 'nœuds']
# words2: ['de', 'la', 'conpiratie', 'à', 'la', 'basés', 'des', 'transformateurs', 'd’intégration']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 2, 0, 1), ('insert', 2, 2, 1, 2), ('equal', 2, 3, 2, 3), ('insert', 3, 3, 3, 4), ('equal', 3, 4, 4, 5), ('replace', 4, 5, 5, 7), ('equal', 5, 7, 7, 9), ('delete', 7, 9, 9, 9)]
# it is ===============================
# index is:  64
# current tp:  1 total tp:  1
# current tp:  1 total tp:  2
# current tp:  1 total tp:  3
# current tp:  2 total tp:  5
# total tp global:  37
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  65
# total tp global:  37
# words1: []
# words2: ['sites', 'de', 'médias']
# opcodes:  [('insert', 0, 0, 0, 3)]
# it is ===============================
# index is:  66
# total tp global:  37
# words1: ['du', 'complot']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  67
# total tp global:  37
# words1: ['tâche', '«FakeNews', 'Detection»,', 'la', 'COVID-19', 'de', 'tweet', 'graphique', 'd’interaction', 'utilisateur.']
# words2: ['«FakeNews', 'Detection»,', 'à', 'la', 'de', 'tweet', 'utilisateur.']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 3, 0, 2), ('insert', 3, 3, 2, 3), ('equal', 3, 4, 3, 4), ('delete', 4, 5, 4, 4), ('equal', 5, 7, 4, 6), ('delete', 7, 9, 6, 6), ('equal', 9, 10, 6, 7)]
# it is ===============================
# index is:  68
# current tp:  2 total tp:  2
# current tp:  1 total tp:  3
# current tp:  2 total tp:  5
# current tp:  1 total tp:  6
# total tp global:  43
# words1: ['Transformer', 'd’intégration', 'de', 'nœuds', 'modèles', 'objectifs', 'de', 'classification.']
# words2: ['d’intégration']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 2, 0, 1), ('delete', 2, 8, 1, 1)]
# it is ===============================
# index is:  69
# current tp:  1 total tp:  1
# total tp global:  44
# words1: ['MCC']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  70
# total tp global:  44
# words1: ["d'exploration", 'de', 'texte']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  71
# total tp global:  44
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  72
# total tp global:  44
# words1: ["d'exploration", 'de', 'texte']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  73
# total tp global:  44
# words1: []
# words2: ['Omnicrobe']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  74
# total tp global:  44
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  75
# total tp global:  44
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  76
# total tp global:  44
# words1: ["l'ontologie", 'Ontobiotope', 'taxons']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  77
# total tp global:  44
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  78
# total tp global:  44
# words1: ['requêtes', 'riches', 'elle']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  79
# total tp global:  44
# words1: ["d'Omnicrobe", 'alimentaire.']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  80
# total tp global:  44
# words1: ['Apprentissage', 'latents', 'dynamique', 'différentiable']
# words2: ['stochastiques']
# opcodes:  [('replace', 0, 4, 0, 1)]
# it is ===============================
# index is:  81
# total tp global:  44
# words1: ['en', 'aval,', "l'arbre."]
# words2: ['Nous', 'dans', 'notre', 'modèle', 'probabiliste']
# opcodes:  [('replace', 0, 3, 0, 5)]
# it is ===============================
# index is:  82
# total tp global:  44
# words1: ['dynamique', 'différentiable.']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  83
# total tp global:  44
# words1: ['de', "l'apprentissage", 'des', 'arbres', 'latents,', 'échantillonnons', 'analyseur', 'syntaxique', 'différentiable.']
# words2: ['stochastiquement']
# opcodes:  [('replace', 0, 9, 0, 1)]
# it is ===============================
# index is:  84
# total tp global:  44
# words1: ['de', "d'inférence", 'du', 'langage', 'naturel.']
# words2: ['de', 'du', 'langage', 'naturel.']
# opcodes:  [('equal', 0, 1, 0, 1), ('delete', 1, 2, 1, 1), ('equal', 2, 5, 1, 4)]
# it is ===============================
# index is:  85
# current tp:  1 total tp:  1
# current tp:  3 total tp:  4
# total tp global:  48
# words1: []
# words2: ['de']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  86
# total tp global:  48
# words1: ["d'ablation", "l'obligation", 'pour', 'les', 'structures', 'latentes', "d'être", 'arbres', 'projectifs.']
# words2: ['stochasticité', 'et', 'de', "l'obligation"]
# opcodes:  [('replace', 0, 1, 0, 3), ('equal', 1, 2, 3, 4), ('delete', 2, 9, 4, 4)]
# it is ===============================
# index is:  87
# current tp:  1 total tp:  1
# total tp global:  49
# words1: ['calibrage', 'estimation', 'la', 'perte', 'de', 'groupement', 'de', 'reseaux', 'neuronaux']
# words2: ['de', 'groupement', 'de', 'reseaux']
# opcodes:  [('delete', 0, 4, 0, 0), ('equal', 4, 8, 0, 4), ('delete', 8, 9, 4, 4)]
# it is ===============================
# index is:  88
# current tp:  4 total tp:  4
# total tp global:  53
# words1: ['classificateur', 'donne', 'scores', 'de', 'confiance', 'éclairée.']
# words2: []
# opcodes:  [('delete', 0, 6, 0, 0)]
# it is ===============================
# index is:  89
# total tp global:  53
# words1: ["d'étalonnage,", 'confiance', 'excessive', 'des', 'scores', 'des']
# words2: []
# opcodes:  [('delete', 0, 6, 0, 0)]
# it is ===============================
# index is:  90
# total tp global:  53
# words1: ["l'étalonnage"]
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  91
# total tp global:  53
# words1: ['perte', 'de', 'regroupement,', 'postérieures', 'vraies']
# words2: ['regroupement,', 'vraies']
# opcodes:  [('delete', 0, 2, 0, 0), ('equal', 2, 3, 0, 1), ('delete', 3, 4, 1, 1), ('equal', 4, 5, 1, 2)]
# it is ===============================
# index is:  92
# current tp:  1 total tp:  1
# current tp:  1 total tp:  2
# total tp global:  55
# words1: ['règles', 'de', 'notation', 'appropriées', 'perte', "d'étalonnage,", 'pièce', 'la', 'perte', 'de', 'regroupement.']
# words2: ['de']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 2, 0, 1), ('delete', 2, 11, 1, 1)]
# it is ===============================
# index is:  93
# current tp:  1 total tp:  1
# total tp global:  56
# words1: ['perte', "d'étalonnage,", 'perte', 'de', 'regroupement']
# words2: ['de']
# opcodes:  [('delete', 0, 3, 0, 0), ('equal', 3, 4, 0, 1), ('delete', 4, 5, 1, 1)]
# it is ===============================
# index is:  94
# current tp:  1 total tp:  1
# total tp global:  57
# words1: ['estimateur', 'perte', 'de', 'groupement.']
# words2: ['de', 'groupement.']
# opcodes:  [('delete', 0, 2, 0, 0), ('equal', 2, 4, 0, 2)]
# it is ===============================
# index is:  95
# current tp:  2 total tp:  2
# total tp global:  59
# words1: ['en', 'PNL', 'perte', 'de', 'groupement,', 'paramètres', 'de', 'distribution,', 'de', 'pré-production.']
# words2: ['PNL', 'de', 'groupement,']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 2, 0, 1), ('delete', 2, 3, 1, 1), ('equal', 3, 5, 1, 3), ('delete', 5, 10, 3, 3)]
# it is ===============================
# index is:  96
# current tp:  1 total tp:  1
# current tp:  2 total tp:  3
# total tp global:  62
# words1: ['instances', 'de', 'relations', 'n-Ary']
# words2: ['n-Ary']
# opcodes:  [('delete', 0, 3, 0, 0), ('equal', 3, 4, 0, 1)]
# it is ===============================
# index is:  97
# current tp:  1 total tp:  1
# total tp global:  63
# words1: ['n-Ary']
# words2: ['n-Ary']
# opcodes:  [('equal', 0, 1, 0, 1)]
# it is ===============================
# index is:  98
# current tp:  1 total tp:  1
# total tp global:  64
# words1: ['n-Ary']
# words2: ['n-Ary', '(OTR)']
# opcodes:  [('equal', 0, 1, 0, 1), ('insert', 1, 1, 1, 2)]
# it is ===============================
# index is:  99
# current tp:  1 total tp:  1
# total tp global:  65
# words1: ['tableaux', 'des', 'instances', "d'arguments"]
# words2: ['n-Ary']
# opcodes:  [('replace', 0, 4, 0, 1)]
# it is ===============================
# index is:  100
# total tp global:  65
# words1: ['Publication', 'représentation', 'des', 'relations', 'n-Ary', 'dite', 'Scientific', 'Table', 'Representation', '(STaRe)', "d'une", 'relation', 'n-Ary', 'STARE', 'fréquentistes', "d'intégration", 'de', 'mots']
# words2: ['n-Ary', 'n-Ary', 'originating', 'from', 'partial', 'n-Ary', 'extracted', 'from', 'document', 'tables),', 'n-Ary', 'fréquentistes', "d'intégration", 'mots', '(word', 'embedding', 'models).']
# opcodes:  [('delete', 0, 4, 0, 0), ('equal', 4, 5, 0, 1), ('delete', 5, 12, 1, 1), ('equal', 12, 13, 1, 2), ('replace', 13, 14, 2, 11), ('equal', 14, 16, 11, 13), ('delete', 16, 17, 13, 13), ('equal', 17, 18, 13, 14), ('insert', 18, 18, 14, 17)]
# it is ===============================
# index is:  101
# current tp:  1 total tp:  1
# current tp:  1 total tp:  2
# current tp:  2 total tp:  4
# current tp:  1 total tp:  5
# total tp global:  70
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  102
# total tp global:  70
# words1: ['instances', 'de', 'relations', 'composées']
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  103
# total tp global:  70
# words1: ['Des', 'corpus', 'de', 'documents', "d'arguments"]
# words2: []
# opcodes:  [('delete', 0, 5, 0, 0)]
# it is ===============================
# index is:  104
# total tp global:  70
# words1: ['f', '0,34', '0,74.']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  105
# total tp global:  70
# words1: ['des', 'relations', 'n-Ary', "d'instances", "d'arguments", 'candidats', 'sélectionnés.']
# words2: ['n-Ary']
# opcodes:  [('delete', 0, 2, 0, 0), ('equal', 2, 3, 0, 1), ('delete', 3, 7, 1, 1)]
# it is ===============================
# index is:  106
# current tp:  1 total tp:  1
# total tp global:  71
# words1: ['Combiner', "l'intégration"]
# words2: ["l'intégration", 'les']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 2, 0, 1), ('insert', 2, 2, 1, 2)]
# it is ===============================
# index is:  107
# current tp:  1 total tp:  1
# total tp global:  72
# words1: ['normaliser', 'les', 'termes', 'multi-mots', 'ontologie']
# words2: ['multi-mots']
# opcodes:  [('delete', 0, 3, 0, 0), ('equal', 3, 4, 0, 1), ('delete', 4, 5, 1, 1)]
# it is ===============================
# index is:  108
# current tp:  1 total tp:  1
# total tp global:  73
# words1: ['normalisation']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  109
# total tp global:  73
# words1: ['sur', "l'intégration", 'des', 'mots']
# words2: ['termes']
# opcodes:  [('replace', 0, 4, 0, 1)]
# it is ===============================
# index is:  110
# total tp global:  73
# words1: ['normalisation', 'non', 'supervisée', 'ToMap', 'formation', 'données', 'de', 'premier', 'résultat', 'rappel.']
# words2: []
# opcodes:  [('delete', 0, 10, 0, 0)]
# it is ===============================
# index is:  111
# total tp global:  73
# words1: ['méthode', 'étiquettes', 'de', 'concepts.']
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  112
# total tp global:  73
# words1: ['apprise']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  113
# total tp global:  73
# words1: ["l'ensemble", 'de', 'données', "d'apprentissage"]
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  114
# total tp global:  73
# words1: ['de', 'distance', 'des', 'vecteurs', 'de', 'termes', 'vecteurs', 'de', 'concepts,', 'concept']
# words2: []
# opcodes:  [('delete', 0, 10, 0, 0)]
# it is ===============================
# index is:  115
# total tp global:  73
# words1: ['tâche', 'catégorisation', 'des', 'habitats', 'bactériens', 'Shared', 'Task']
# words2: []
# opcodes:  [('delete', 0, 7, 0, 0)]
# it is ===============================
# index is:  116
# total tp global:  73
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  117
# total tp global:  73
# words1: ['Amorçage', 'de', 'la', 'traduction', 'automatique', 'de', 'neurones']
# words2: ['de', 'neurones']
# opcodes:  [('delete', 0, 5, 0, 0), ('equal', 5, 7, 0, 2)]
# it is ===============================
# index is:  118
# current tp:  2 total tp:  2
# total tp global:  75
# words1: ['L’amorçage']
# words2: ['(cue)']
# opcodes:  [('replace', 0, 1, 0, 1)]
# it is ===============================
# index is:  119
# total tp global:  75
# words1: ['cadre', 'd’amorçage']
# words2: ['(NMT).']
# opcodes:  [('replace', 0, 2, 0, 1)]
# it is ===============================
# index is:  120
# total tp global:  75
# words1: ['indices', 'd’amorçage']
# words2: ['NMT.']
# opcodes:  [('replace', 0, 2, 0, 1)]
# it is ===============================
# index is:  121
# total tp global:  75
# words1: ['d’amorçage', 'comparer', 'la', 'micro-adaptation', 'pendant', 'l’inférence.']
# words2: ['NMT', 'framework']
# opcodes:  [('replace', 0, 6, 0, 2)]
# it is ===============================
# index is:  122
# total tp global:  75
# words1: ['multi-domaines', 'd’indicateurs', 'd’amorçage']
# words2: ['NMT']
# opcodes:  [('replace', 0, 3, 0, 1)]
# it is ===============================
# index is:  123
# total tp global:  75
# words1: ['responsabilité', 'internationales']
# words2: ['internationales']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 2, 0, 1)]
# it is ===============================
# index is:  124
# current tp:  1 total tp:  1
# total tp global:  76
# words1: []
# words2: ['global']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  125
# total tp global:  76
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  126
# total tp global:  76
# words1: ['Tirer', 'génération', 'données', 'à', 'texte', 'd’information']
# words2: ['de', 'données', 'à', 'texte', '-Abstract']
# opcodes:  [('replace', 0, 2, 0, 1), ('equal', 2, 5, 1, 4), ('replace', 5, 6, 4, 5)]
# it is ===============================
# index is:  127
# current tp:  3 total tp:  3
# total tp global:  79
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  128
# total tp global:  79
# words1: ['génératifs', 'génération', 'de', 'données', 'au', 'texte.']
# words2: ['de', 'données', 'au', 'texte.']
# opcodes:  [('delete', 0, 2, 0, 0), ('equal', 2, 6, 0, 4)]
# it is ===============================
# index is:  129
# current tp:  4 total tp:  4
# total tp global:  83
# words1: ['planification']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  130
# total tp global:  83
# words1: ['l’ensemble']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  131
# total tp global:  83
# words1: ['planification', 'modèle', 'texte-texte.']
# words2: ['correspondante', 'texte-texte.']
# opcodes:  [('replace', 0, 2, 0, 1), ('equal', 2, 3, 1, 2)]
# it is ===============================
# index is:  132
# current tp:  1 total tp:  1
# total tp global:  84
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  133
# total tp global:  84
# words1: ['Modèles', 'de', 'langage', 'pondérés', 'symboliques,']
# words2: []
# opcodes:  [('delete', 0, 5, 0, 0)]
# it is ===============================
# index is:  134
# total tp global:  84
# words1: ['de', 'formalismes', 'symboliques', 'pondérés:', 'automates', '(SWA),', 'transducteurs', '(SWT)', 'et', 'extensions', 'visibles', 'de', 'poussée', '(swVPA,', 'swVPT).']
# words2: ['pondérés:', '(SWA),', '(SWT)']
# opcodes:  [('delete', 0, 3, 0, 0), ('equal', 3, 4, 0, 1), ('delete', 4, 5, 1, 1), ('equal', 5, 6, 1, 2), ('delete', 6, 7, 2, 2), ('equal', 7, 8, 2, 3), ('delete', 8, 15, 3, 3)]
# it is ===============================
# index is:  135
# current tp:  1 total tp:  1
# current tp:  1 total tp:  2
# current tp:  1 total tp:  3
# total tp global:  87
# words1: ['extensions', 'homologues', 'symboliques', 'et', 'pondérés,', 'alphabet', 'd’entrée', 'grand', 'ou', 'infini.']
# words2: []
# opcodes:  [('delete', 0, 10, 0, 0)]
# it is ===============================
# index is:  136
# total tp global:  87
# words1: ['fermeture', 'par', 'composition,', 'transducteur', 'mots', 'imbriqués', 'langues,', 'recherche', 'PTIME', '1-meilleur', 'pour', 'swVPA.']
# words2: ['qu’un', 'algorithme', 'PTIME', '1-meilleur', 'swVPA.']
# opcodes:  [('replace', 0, 8, 0, 2), ('equal', 8, 10, 2, 4), ('delete', 10, 11, 4, 4), ('equal', 11, 12, 4, 5)]
# it is ===============================
# index is:  137
# current tp:  2 total tp:  2
# current tp:  1 total tp:  3
# total tp global:  90
# words1: ['résoudre', 'PTIME', 'de', 'l’analyse', 'sur', 'infinis.']
# words2: []
# opcodes:  [('delete', 0, 6, 0, 0)]
# it is ===============================
# index is:  138
# total tp global:  90
# words1: ['motivant']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  139
# total tp global:  90
# words1: ['Cadre', "d'apprentissage", 'contrastif', 'textuelles']
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  140
# total tp global:  90
# words1: []
# words2: ['neuronaux', '(DNN)']
# opcodes:  [('insert', 0, 0, 0, 2)]
# it is ===============================
# index is:  141
# total tp global:  90
# words1: ['fonction', 'objective', 'de', "l'entropie", 'croisée.']
# words2: []
# opcodes:  [('delete', 0, 5, 0, 0)]
# it is ===============================
# index is:  142
# total tp global:  90
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  143
# total tp global:  90
# words1: ['auto-supervisé', 'de', 'représentations', 'contrastives,', 'contrastif']
# words2: []
# opcodes:  [('delete', 0, 5, 0, 0)]
# it is ===============================
# index is:  144
# total tp global:  90
# words1: ['pré-entraînons', 'nouvelle', 'perte', 'contrastive', 'entièrement', 'supervisée.']
# words2: []
# opcodes:  [('delete', 0, 6, 0, 0)]
# it is ===============================
# index is:  145
# total tp global:  90
# words1: ['séparabilité', 'inter-classes', 'compacité', 'intra-classe', 'encastrements', "l'espace", 'latent.']
# words2: ['inter-classes', 'intra-classe', 'encastrements']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 2, 0, 1), ('delete', 2, 3, 1, 1), ('equal', 3, 5, 1, 3), ('delete', 5, 7, 3, 3)]
# it is ===============================
# index is:  146
# current tp:  1 total tp:  1
# current tp:  2 total tp:  3
# total tp global:  93
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  147
# total tp global:  93
# words1: ['sélectionner', 'les', 'négatifs', 'durs', "d'apprentissage."]
# words2: []
# opcodes:  [('delete', 0, 5, 0, 0)]
# it is ===============================
# index is:  148
# total tp global:  93
# words1: ['du', 'lot).']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  149
# total tp global:  93
# words1: ["d'augmentations", 'de', 'données,']
# words2: ['benchmarks']
# opcodes:  [('replace', 0, 3, 0, 1)]
# it is ===============================
# index is:  150
# total tp global:  93
# words1: ['61,94', "l'ensemble", 'de', 'données', 'Amazon-F,', "l'entropie", 'croisée', 'de']
# words2: []
# opcodes:  [('delete', 0, 8, 0, 0)]
# it is ===============================
# index is:  151
# total tp global:  93
# words1: ['score', 'de', 'communication', 'holistique']
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  152
# total tp global:  93
# words1: ['Contexte']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  153
# total tp global:  93
# words1: ['parole,']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  154
# total tp global:  93
# words1: ['auto-administrés', 'limitations', 'générales', "d'activité,"]
# words2: ['auto-administrés']
# opcodes:  [('equal', 0, 1, 0, 1), ('delete', 1, 4, 1, 1)]
# it is ===============================
# index is:  155
# current tp:  1 total tp:  1
# total tp global:  94
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  156
# total tp global:  94
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  157
# total tp global:  94
# words1: ['Objectif']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  158
# total tp global:  94
# words1: ['parole']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  159
# total tp global:  94
# words1: ['Procédures']
# words2: ['&']
# opcodes:  [('replace', 0, 1, 0, 1)]
# it is ===============================
# index is:  160
# total tp global:  94
# words1: ['auto-questionnaires', 'parole', 'QLQ-C30', 'QLQ-H&N35).']
# words2: ['auto-questionnaires', 'QLQ-H&N35).']
# opcodes:  [('equal', 0, 1, 0, 1), ('delete', 1, 3, 1, 1), ('equal', 3, 4, 1, 2)]
# it is ===============================
# index is:  161
# current tp:  1 total tp:  1
# current tp:  1 total tp:  2
# total tp global:  96
# words1: ['Cent', 'soixante-quatorze']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  162
# total tp global:  96
# words1: ['de', 'dimensionnalité']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  163
# total tp global:  96
# words1: ['de', 'la', 'validité', 'apparente', 'orthophonie,']
# words2: []
# opcodes:  [('delete', 0, 5, 0, 0)]
# it is ===============================
# index is:  164
# total tp global:  96
# words1: ['de', 'la', 'validité', 'de', 'construction', 'redondants', 'insuffisamment', 'variables.']
# words2: []
# opcodes:  [('delete', 0, 8, 0, 0)]
# it is ===============================
# index is:  165
# total tp global:  96
# words1: ['score', 'de', 'communication', 'holistique', '(facteur', 'à', 'composante', 'principale)', 'de', 'profil', 'latent.']
# words2: []
# opcodes:  [('delete', 0, 11, 0, 0)]
# it is ===============================
# index is:  166
# total tp global:  96
# words1: ['Résultats']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  167
# total tp global:  96
# words1: ['cavité', 'buccale', 'deux', 'localisations']
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  168
# total tp global:  96
# words1: ['la', 'validité', 'apparente,']
# words2: ['(Kappa>0,80).']
# opcodes:  [('replace', 0, 3, 0, 1)]
# it is ===============================
# index is:  169
# total tp global:  96
# words1: []
# words2: ['(r>0,90)']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  170
# total tp global:  96
# words1: ['Quarante', "l'analyse", 'factorielle.']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  171
# total tp global:  96
# words1: ['du', 'score', 'post-analyse', '(moyenne=100', 'écart-type=10).']
# words2: []
# opcodes:  [('delete', 0, 5, 0, 0)]
# it is ===============================
# index is:  172
# total tp global:  96
# words1: ['score', 'de', 'communication', 'holistique', 'dynamique', 'perception', 'des', 'troubles', 'de', 'la', 'parole']
# words2: ['QLQ-H&N35).']
# opcodes:  [('replace', 0, 11, 0, 1)]
# it is ===============================
# index is:  173
# total tp global:  96
# words1: ['fiabilité', '(validation', 'croisée', 'cinq', 'fois', 'latent', 'performance']
# words2: []
# opcodes:  [('delete', 0, 7, 0, 0)]
# it is ===============================
# index is:  174
# total tp global:  96
# words1: []
# words2: ['Implications']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  175
# total tp global:  96
# words1: ['trouble', 'de', 'la', 'parole']
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  176
# total tp global:  96
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  177
# total tp global:  96
# words1: ['prédire', 'Classification', 'des', 'actes', 'de', 'parole']
# words2: ['Donnez-moi', 'actions:', 'parole', 'dans', 'médias']
# opcodes:  [('replace', 0, 5, 0, 2), ('equal', 5, 6, 2, 3), ('insert', 6, 6, 3, 5)]
# it is ===============================
# index is:  178
# current tp:  1 total tp:  1
# total tp global:  97
# words1: ['promus', 'actes', 'de', 'parole', 'informatique', 'de', 'PNL', 'en', 'aval.']
# words2: ['(Austin,', '1962)', '(Searle,', '1975),', 'parole', '(SA)', 'de', 'SA', 'de', 'PNL', 'aval.']
# opcodes:  [('replace', 0, 2, 0, 6), ('equal', 2, 3, 6, 7), ('replace', 3, 5, 7, 8), ('equal', 5, 7, 8, 10), ('delete', 7, 8, 10, 10), ('equal', 8, 9, 10, 11)]
# it is ===============================
# index is:  179
# current tp:  1 total tp:  1
# current tp:  2 total tp:  3
# current tp:  1 total tp:  4
# total tp global:  101
# words1: ['de', 'l’AS', 'sur', 'des', 'urgences']
# words2: ['de', 'l’AS']
# opcodes:  [('equal', 0, 2, 0, 2), ('delete', 2, 5, 2, 2)]
# it is ===============================
# index is:  180
# current tp:  2 total tp:  2
# total tp global:  103
# words1: ['l’AS', 'est', 'pertinente', 'matière', 'd’action,', 'exploitables', 'humaines']
# words2: ['l’AS', 'est', 'pertinente']
# opcodes:  [('equal', 0, 3, 0, 3), ('delete', 3, 7, 3, 3)]
# it is ===============================
# index is:  181
# current tp:  3 total tp:  3
# total tp global:  106
# words1: []
# words2: ['principales:']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  182
# total tp global:  106
# words1: ['d’annotation', 'de', 'SA', 'tweet', 'du', 'sous-tweet,', 'jeu', 'de', 'données', 'français', '6', '669', 'l’urgence', 'pour', 'SA,', 'catégories', 'd’urgence,', 'd’apprentissage', 'profond', 'la', 'SA', 'corpus', 'de', 'crise.']
# words2: ['Un', 'de', 'SA', 'sous-tweet,', 'Un', 'SA,', 'Une', 'SA', 'Un', 'la', 'SA']
# opcodes:  [('replace', 0, 1, 0, 1), ('equal', 1, 3, 1, 3), ('delete', 3, 5, 3, 3), ('equal', 5, 6, 3, 4), ('replace', 6, 14, 4, 5), ('equal', 14, 15, 5, 6), ('replace', 15, 19, 6, 9), ('equal', 19, 21, 9, 11), ('delete', 21, 24, 11, 11)]
# it is ===============================
# index is:  183
# current tp:  2 total tp:  2
# current tp:  1 total tp:  3
# current tp:  1 total tp:  4
# current tp:  2 total tp:  6
# total tp global:  112
# words1: ['l’AS', 'est', 'corrélée', 'l’urgence,', 'une', 'crises', 'basée', 'sur', 'la', 'PNL', 'basée', 'sur', 'les', 'SA', 'médias']
# words2: ['l’AS', 'est', 'corrélée', 'basée', 'sur', 'la', 'PNL', 'basée', 'SA', 'sur', 'les', 'médias']
# opcodes:  [('equal', 0, 3, 0, 3), ('delete', 3, 6, 3, 3), ('equal', 6, 11, 3, 8), ('insert', 11, 11, 8, 9), ('equal', 11, 13, 9, 11), ('delete', 13, 14, 11, 11), ('equal', 14, 15, 11, 12)]
# it is ===============================
# index is:  184
# current tp:  3 total tp:  3
# current tp:  5 total tp:  8
# current tp:  2 total tp:  10
# current tp:  1 total tp:  11
# total tp global:  123
# words1: ['données', 'en', 'texte']
# words2: ['en', 'texte']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 3, 0, 2)]
# it is ===============================
# index is:  185
# current tp:  2 total tp:  2
# total tp global:  125
# words1: ['Transcrire', 'descriptions', 'naturel', 'apparu', 'appelée', '«', 'données-texte', '».']
# words2: ['données-texte']
# opcodes:  [('delete', 0, 6, 0, 0), ('equal', 6, 7, 0, 1), ('delete', 7, 8, 1, 1)]
# it is ===============================
# index is:  186
# current tp:  1 total tp:  1
# total tp global:  126
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  187
# total tp global:  126
# words1: ['de', 'codage-décodage', 'de', 'traduction', 'linéarisent', 'en']
# words2: []
# opcodes:  [('delete', 0, 6, 0, 0)]
# it is ===============================
# index is:  188
# total tp global:  126
# words1: ['Ceci', 'perd']
# words2: ['Ceci', 'perd', 'cependant', 'données.']
# opcodes:  [('equal', 0, 2, 0, 2), ('insert', 2, 2, 2, 4)]
# it is ===============================
# index is:  189
# current tp:  2 total tp:  2
# total tp global:  128
# words1: ['code', 'structure.']
# words2: ['élément']
# opcodes:  [('replace', 0, 2, 0, 1)]
# it is ===============================
# index is:  190
# total tp global:  128
# words1: ['RotoWire', 'w.r.t.', 'mesures']
# words2: ['mesures', 'qualitatives', 'et', 'quantitatives.']
# opcodes:  [('delete', 0, 2, 0, 0), ('equal', 2, 3, 0, 1), ('insert', 3, 3, 1, 4)]
# it is ===============================
# index is:  191
# current tp:  1 total tp:  1
# total tp global:  129
# words1: ['développer', 'des', 'inhibitions']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  192
# total tp global:  129
# words1: ['de', 'recettes', 'des', 'succès', 'passés', 'opérateurs', 'féconds', 'directions', 'de', 'mutation', 'fécondes).']
# words2: ['concernés', 'par', 'succès', 'passés', '(par', 'exemple', 'féconds', 'fécondes).']
# opcodes:  [('replace', 0, 3, 0, 2), ('equal', 3, 5, 2, 4), ('replace', 5, 6, 4, 6), ('equal', 6, 7, 6, 7), ('delete', 7, 10, 7, 7), ('equal', 10, 11, 7, 8)]
# it is ===============================
# index is:  193
# current tp:  2 total tp:  2
# current tp:  1 total tp:  3
# current tp:  1 total tp:  4
# total tp global:  133
# words1: ['piste', 'opp', 'opposée,', 'mémorise', 'passés', '(descendance', 'inapte)']
# words2: ['la', 'piste', 'opp', 'opposée,']
# opcodes:  [('insert', 0, 0, 0, 1), ('equal', 0, 3, 1, 4), ('delete', 3, 7, 4, 4)]
# it is ===============================
# index is:  194
# current tp:  3 total tp:  3
# total tp global:  136
# words1: ['la', 'progéniture', "s'éloigner", 'plus', 'du', 'perdant', 'virtuel', 'que']
# words2: ['la', 'progéniture', 'essayer', 'de', "s'éloigner"]
# opcodes:  [('equal', 0, 2, 0, 2), ('insert', 2, 2, 2, 4), ('equal', 2, 3, 4, 5), ('delete', 3, 8, 5, 5)]
# it is ===============================
# index is:  195
# current tp:  2 total tp:  2
# current tp:  1 total tp:  3
# total tp global:  139
# words1: ['opérateur', "d'évolution,", 'fugue-mutation,', 'recombinaison', 'et', 'mutation']
# words2: ['Ceci', 'est', 'fugue-mutation,']
# opcodes:  [('replace', 0, 2, 0, 2), ('equal', 2, 3, 2, 3), ('delete', 3, 6, 3, 3)]
# it is ===============================
# index is:  196
# current tp:  1 total tp:  1
# total tp global:  140
# words1: ["l'ajustement", 'du', 'pas', 'de', 'mutation', 'de', 'la', 'puce.']
# words2: ['du', 'pas', 'la', 'puce.']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 3, 0, 2), ('delete', 3, 6, 2, 2), ('equal', 6, 8, 2, 4)]
# it is ===============================
# index is:  197
# current tp:  2 total tp:  2
# current tp:  2 total tp:  4
# total tp global:  144
# words1: ['de', 'taille', 'de', 'mutation', 'de', 'fuite', 'sur']
# words2: ['de', 'taille']
# opcodes:  [('equal', 0, 2, 0, 2), ('delete', 2, 7, 2, 2)]
# it is ===============================
# index is:  198
# current tp:  2 total tp:  2
# total tp global:  146
# words1: ['évolutive']
# words2: ['Cartolabe:', 'évolutive', 'basée', 'sur', 'le', 'Web', 'des']
# opcodes:  [('insert', 0, 0, 0, 1), ('equal', 0, 1, 1, 2), ('insert', 1, 1, 2, 7)]
# it is ===============================
# index is:  199
# current tp:  1 total tp:  1
# total tp global:  147
# words1: ['multi-échelle', 'requêtes', 'filtrantes.']
# words2: ['basé', 'Web', 'basés', 'sur', 'sujets,']
# opcodes:  [('replace', 0, 3, 0, 5)]
# it is ===============================
# index is:  200
# total tp global:  147
# words1: ['représenter', 'et', 'naviguer', 'corpus,', 'débat', 'national', 'français', '(4,3', 'millions', 'd’entrées).']
# words2: []
# opcodes:  [('delete', 0, 10, 0, 0)]
# it is ===============================
# index is:  201
# total tp global:  147
# words1: ['convertissant', 'étiquettes']
# words2: ['modules:']
# opcodes:  [('replace', 0, 2, 0, 1)]
# it is ===============================
# index is:  202
# total tp global:  147
# words1: ['tuiles', 'projection']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  203
# total tp global:  147
# words1: ['lui:', 'explorer,', 'interroger,', 'panoramiquer', 'zoomer', 'régions']
# words2: ['lui:']
# opcodes:  [('equal', 0, 1, 0, 1), ('delete', 1, 6, 1, 1)]
# it is ===============================
# index is:  204
# current tp:  1 total tp:  1
# total tp global:  148
# words1: ['d’utilisation', 'polyvalence', 'textuelles']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  205
# total tp global:  148
# words1: ['ÉCART', ':', 'Réseaux', 'privé', 'perturbation', "d'agrégation"]
# words2: ['ÉCART']
# opcodes:  [('equal', 0, 1, 0, 1), ('delete', 1, 6, 1, 1)]
# it is ===============================
# index is:  206
# current tp:  1 total tp:  1
# total tp global:  149
# words1: ['neurones', 'graphiques', 'la', 'confidentialité', 'différentielle']
# words2: ['(GNNs)', '(DP).']
# opcodes:  [('replace', 0, 5, 0, 2)]
# it is ===============================
# index is:  207
# total tp global:  149
# words1: ['GNN', 'différentiellement', 'privé', 'la', 'Perturbation', "d'Agrégation", '(GAP),', 'bruit', 'obscurcir', 'bord', '(confidentialité', 'du', 'bord)', 'noeud', 'bords', '(confidentialité', 'du', 'noeud).']
# words2: ['basé', 'Perturbation', "d'Agrégation", '(GAP),', 'noeud', 'noeud).']
# opcodes:  [('replace', 0, 4, 0, 1), ('equal', 4, 7, 1, 4), ('delete', 7, 13, 4, 4), ('equal', 13, 14, 4, 5), ('delete', 14, 17, 5, 5), ('equal', 17, 18, 5, 6)]
# it is ===============================
# index is:  208
# current tp:  3 total tp:  3
# current tp:  1 total tp:  4
# current tp:  1 total tp:  5
# total tp global:  154
# words1: ['encodeur,', "d'agrégation,", 'calculons', 'les', 'noyaux', 'agrégés', 'bruités', 'incorporés', 'forme']
# words2: ['noeuds', 'périphérie', ';', 'graphique', ';', 'noeuds']
# opcodes:  [('replace', 0, 9, 0, 6)]
# it is ===============================
# index is:  209
# total tp global:  154
# words1: ['GAP', 'précédentes', "d'agrégations", 'de', 'voisinage', 'multi-saut,', 'garantit', 'le', 'DP', 'au', 'la', 'périphérie', 'au', 'du', 'noeud,', 'formation,', 'en', 'inférence,', 'coûts', 'supplémentaires', 'au-delà', 'budget', 'de', 'confidentialité', 'de', 'la', 'formation.']
# words2: ['multi-saut,', 'le', 'DP', 'noeud,']
# opcodes:  [('delete', 0, 5, 0, 0), ('equal', 5, 6, 0, 1), ('delete', 6, 7, 1, 1), ('equal', 7, 9, 1, 3), ('delete', 9, 14, 3, 3), ('equal', 14, 15, 3, 4), ('delete', 15, 27, 4, 4)]
# it is ===============================
# index is:  210
# current tp:  1 total tp:  1
# current tp:  2 total tp:  3
# current tp:  1 total tp:  4
# total tp global:  158
# words1: ['données', 'graphiques', 'réels.']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  211
# total tp global:  158
# words1: []
# words2: ['basées']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  212
# total tp global:  158
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# ...
# words1: ['floues,', 'floues,']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  1822
# total tp global:  1558
# words1: ['peu', 'nombreuses,', 'ou', 'linguistiques,', 'des', 'observations', 'imprécises', 'ou', 'linguistiques.']
# words2: []
# opcodes:  [('delete', 0, 9, 0, 0)]
# it is ===============================
# index is:  1823
# total tp global:  1558
# words1: []
# words2: ['interpolatif']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  1824
# total tp global:  1558
# words1: ['existant', 'dans', "l'état", 'de', "l'art", 'exigences', 'de', "l'Intelligence", 'Artificielle', '(IA)', 'explicable.']
# words2: []
# opcodes:  [('delete', 0, 11, 0, 0)]
# it is ===============================
# index is:  1825
# total tp global:  1558
# words1: ['raisonnement', 'flou', 'construire.']
# words2: ['interpolatif']
# opcodes:  [('replace', 0, 3, 0, 1)]
# it is ===============================
# index is:  1826
# total tp global:  1558
# words1: ['raisonnement', 'interpolatif', 'flou', 'existantes']
# words2: ['interpolatif']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 2, 0, 1), ('delete', 2, 4, 1, 1)]
# it is ===============================
# index is:  1827
# current tp:  1 total tp:  1
# total tp global:  1559
# words1: ['Adaptation', 'de', 'l’ontologie', 'pour', 'l’exploitation', 'minière', 'd’opinions', 'en', 'Corpora', 'français']
# words2: ['l’exploitation', 'minière', 'en', 'Corpora']
# opcodes:  [('delete', 0, 4, 0, 0), ('equal', 4, 6, 0, 2), ('delete', 6, 7, 2, 2), ('equal', 7, 9, 2, 4), ('delete', 9, 10, 4, 4)]
# it is ===============================
# index is:  1828
# current tp:  2 total tp:  2
# current tp:  2 total tp:  4
# total tp global:  1563
# words1: ['l’extraction', 'corpus']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  1829
# total tp global:  1563
# words1: ['d’évaluation', 'de', 'modélisation']
# words2: ['existantes']
# opcodes:  [('replace', 0, 3, 0, 1)]
# it is ===============================
# index is:  1830
# total tp global:  1563
# words1: []
# words2: ['principales:', 'conceptuelle;']
# opcodes:  [('insert', 0, 0, 0, 2)]
# it is ===============================
# index is:  1831
# total tp global:  1563
# words1: ['l’exploration', 'de', 'texte,']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  1832
# total tp global:  1563
# words1: ['traduction', 'concept-to-concept,', 'corpus', 'et', 'externes,']
# words2: ['concept-to-concept,']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 2, 0, 1), ('delete', 2, 5, 1, 1)]
# it is ===============================
# index is:  1833
# current tp:  1 total tp:  1
# total tp global:  1564
# words1: ['conçue', 'construite', 'intégrer', 'des', 'informations', 'linguistiques', 'et', 'linguistiques', 'supplémentaires', 'sur', 'des', 'opinions']
# words2: []
# opcodes:  [('delete', 0, 12, 0, 0)]
# it is ===============================
# index is:  1834
# total tp global:  1564
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  1835
# total tp global:  1564
# words1: ['BigScience', 'modèle', 'multilingue', 'de', 'grandes', 'langues']
# words2: ['de', 'grandes', 'langues']
# opcodes:  [('delete', 0, 3, 0, 0), ('equal', 3, 6, 0, 3)]
# it is ===============================
# index is:  1836
# current tp:  3 total tp:  3
# total tp global:  1567
# words1: ["L'atelier", 'BigScience', 'était', 'axée', 'la', 'valeur', 'ensemble', 'multilingue', 'de', '1,6', 'To', 'former']
# words2: ["L'atelier", 'linguistiques']
# opcodes:  [('equal', 0, 1, 0, 1), ('replace', 1, 12, 1, 2)]
# it is ===============================
# index is:  1837
# current tp:  1 total tp:  1
# total tp global:  1568
# words1: ['artefacts,', "l'atelier", 'grands', 'modèles,']
# words2: ['artefacts,']
# opcodes:  [('equal', 0, 1, 0, 1), ('delete', 1, 4, 1, 1)]
# it is ===============================
# index is:  1838
# current tp:  1 total tp:  1
# total tp global:  1569
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  1839
# total tp global:  1569
# words1: ['document', 'BigScience', 'prend', 'peu', 'de', 'recul']
# words2: []
# opcodes:  [('delete', 0, 6, 0, 0)]
# it is ===============================
# index is:  1840
# total tp global:  1569
# words1: ['bien', 'fait.']
# words2: ['apprises']
# opcodes:  [('replace', 0, 2, 0, 1)]
# it is ===============================
# index is:  1841
# total tp global:  1569
# words1: []
# words2: ['artefacts']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  1842
# total tp global:  1569
# words1: ['du', 'transformateur', 'résumer', 'les', 'représentations', 'synthétiques:', 'accord', 'à', 'longue']
# words2: ['du', 'transformateur', 'synthétiques:']
# opcodes:  [('equal', 0, 2, 0, 2), ('delete', 2, 5, 2, 2), ('equal', 5, 6, 2, 3), ('delete', 6, 9, 3, 3)]
# it is ===============================
# index is:  1843
# current tp:  2 total tp:  2
# current tp:  1 total tp:  3
# total tp global:  1572
# words1: ['transformateurs', 'l’accord', 'découvrir']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  1844
# total tp global:  1572
# words1: ['a', 'constaté', 'les', 'transformateurs', 'l’accord', 'de', 'participation', 'passé', 'objet', 'grammaire', 'subject-verbe', 'résolution', 'anaphora.']
# words2: ['a', 'de', 'participation', 'objet', 'subject-verbe', 'anaphora.']
# opcodes:  [('equal', 0, 1, 0, 1), ('delete', 1, 5, 1, 1), ('equal', 5, 7, 1, 3), ('delete', 7, 8, 3, 3), ('equal', 8, 9, 3, 4), ('delete', 9, 10, 4, 4), ('equal', 10, 11, 4, 5), ('delete', 11, 12, 5, 5), ('equal', 12, 13, 5, 6)]
# it is ===============================
# index is:  1845
# current tp:  1 total tp:  1
# current tp:  2 total tp:  3
# current tp:  1 total tp:  4
# current tp:  1 total tp:  5
# current tp:  1 total tp:  6
# total tp global:  1578
# words1: ['contraster', 'gèrent', 'd’accords.']
# words2: []
# opcodes:  [('delete', 0, 3, 0, 0)]
# it is ===============================
# index is:  1846
# total tp global:  1578
# words1: ['sondage', 'contrefactuelle,', 'accords', 'français', 'tâche', 'de', 'l’accord', 'confusion', 'transformateurs', 'manipulent', 'des', 'accords', 'subject-verbe', 'et', 'participle', 'objet-passé']
# words2: ['subject-verbe', 'participle', 'objet-passé']
# opcodes:  [('delete', 0, 12, 0, 0), ('equal', 12, 13, 0, 1), ('delete', 13, 14, 1, 1), ('equal', 14, 16, 1, 3)]
# it is ===============================
# index is:  1847
# current tp:  1 total tp:  1
# current tp:  2 total tp:  3
# total tp global:  1581
# words1: ['Daniel', 'à', 'la', 'tâche', 'FinSBD-2:', 'Extraction', 'des', 'listes', 'et', 'des', 'peines', 'à', 'partir', 'de', 'de', 'bout', 'en', 'bout', 'axée', 'sur', 'le', 'modèle']
# words2: ['Daniel', 'FinSBD-2:', 'des', 'des', 'peines', 'PDF:']
# opcodes:  [('equal', 0, 1, 0, 1), ('delete', 1, 4, 1, 1), ('equal', 4, 5, 1, 2), ('delete', 5, 6, 2, 2), ('equal', 6, 7, 2, 3), ('delete', 7, 9, 3, 3), ('equal', 9, 11, 3, 5), ('replace', 11, 22, 5, 6)]
# it is ===============================
# index is:  1848
# current tp:  1 total tp:  1
# current tp:  1 total tp:  2
# current tp:  1 total tp:  3
# current tp:  2 total tp:  5
# total tp global:  1586
# words1: ['listes', 'phrases', 'tâche', 'partagée', 'FinSBD-2', 'Analyse', 'des', 'documents', 'financiers.']
# words2: ['FinSBD-2', 'Analyse', 'financiers.']
# opcodes:  [('delete', 0, 4, 0, 0), ('equal', 4, 6, 0, 2), ('delete', 6, 8, 2, 2), ('equal', 8, 9, 2, 3)]
# it is ===============================
# index is:  1849
# current tp:  2 total tp:  2
# current tp:  1 total tp:  3
# total tp global:  1589
# words1: ['pour']
# words2: ['basée']
# opcodes:  [('replace', 0, 1, 0, 1)]
# it is ===============================
# index is:  1850
# total tp global:  1589
# words1: ['processus', 'descendant', 'du', 'PDF', 'lui-même', 'flux', 'de']
# words2: []
# opcodes:  [('delete', 0, 7, 0, 0)]
# it is ===============================
# index is:  1851
# total tp global:  1589
# words1: ['l’extraction', 'de', 'structure', 'PDF', 'des', 'limites', 'de', 'segment', 'de', 'texte', 'de', 'bout', 'en', 'bout.']
# words2: []
# opcodes:  [('delete', 0, 14, 0, 0)]
# it is ===============================
# index is:  1852
# total tp global:  1589
# words1: ['Utilisation', "d'une", 'transformée', 'de', 'Fourier', 'de', 'courte', 'durée', 'démodulation', 'la', 'synchronisation', 'récupération', 'modes', 'de', 'signaux', 'multicomposants']
# words2: ['la', 'synchronisation']
# opcodes:  [('delete', 0, 9, 0, 0), ('equal', 9, 11, 0, 2), ('delete', 11, 16, 2, 2)]
# it is ===============================
# index is:  1853
# current tp:  2 total tp:  2
# total tp global:  1591
# words1: ['temporelles-fréquentielles', '(TF)', 'modes', 'de', 'signaux', 'multicomposants', '(MCS).']
# words2: ['temporelles-fréquentielles']
# opcodes:  [('equal', 0, 1, 0, 1), ('delete', 1, 7, 1, 1)]
# it is ===============================
# index is:  1854
# current tp:  1 total tp:  1
# total tp global:  1592
# words1: ['la', 'transformée', 'de', 'synchronisation', 'temps-fréquence', 'modes', 'des', 'MCS,', 'SST', 'récupération', 'de', 'mode', 'transformée', 'de', 'Fourier', 'à', 'court', 'terme', 'sous-échantillonnée', '(STFT)']
# words2: ['synchronisation']
# opcodes:  [('delete', 0, 3, 0, 0), ('equal', 3, 4, 0, 1), ('delete', 4, 20, 1, 1)]
# it is ===============================
# index is:  1855
# current tp:  1 total tp:  1
# total tp global:  1593
# words1: ['réduit', 'le', 'mélange', 'de', 'modes.']
# words2: ['mélange', 'de', 'modes.']
# opcodes:  [('delete', 0, 2, 0, 0), ('equal', 2, 5, 0, 3)]
# it is ===============================
# index is:  1856
# current tp:  3 total tp:  3
# total tp global:  1596
# words1: ['de', 'fréquence', 'pour', 'modes', 'résolution', 'en', 'fréquence.']
# words2: []
# opcodes:  [('delete', 0, 7, 0, 0)]
# it is ===============================
# index is:  1857
# total tp global:  1596
# words1: []
# words2: ['une']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  1858
# total tp global:  1596
# words1: ['normalisation', 'haleine.']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  1859
# total tp global:  1596
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  1860
# total tp global:  1596
# words1: ['entrave', 'pipelines,', 'des', 'pipelines']
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  1861
# total tp global:  1596
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  1862
# total tp global:  1596
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  1863
# total tp global:  1596
# words1: ['triplestore', 'RDF', 'réseaux', "d'interaction", 'TF-gènes', 'requêtes']
# words2: ['TF-gènes']
# opcodes:  [('delete', 0, 4, 0, 0), ('equal', 4, 5, 0, 1), ('delete', 5, 6, 1, 1)]
# it is ===============================
# index is:  1864
# current tp:  1 total tp:  1
# total tp global:  1597
# words1: ['triplestore', 'stockait', 'réseaux', 'calculés', "n'intégrait", 'échantillons,', 'réutilisation', 'jeu', 'de', 'données.']
# words2: []
# opcodes:  [('delete', 0, 10, 0, 0)]
# it is ===============================
# index is:  1865
# total tp global:  1597
# words1: ['seulement']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  1866
# total tp global:  1597
# words1: ['limitations', 'la', 'conception', 'réutilisable', 'de', 'circuits', 'de', 'régulation,', 'Web', 'sémantique', ':']
# words2: []
# opcodes:  [('delete', 0, 11, 0, 0)]
# it is ===============================
# index is:  1867
# total tp global:  1597
# words1: ['Nous', 'fournissons', 'une', 'représentation', 'RDF', 'modulaire', 'des', 'circuits', 'appelée', 'Linked', 'Extended', 'Regulatory', 'Circuits', '(LERC).', 'expérimental', 'TF-gène', 'annotations', 'connaissances']
# words2: ['Nous', 'fournissons', 'une', 'représentation', 'RDF', 'modulaire', 'des', 'circuits', 'de', 'régulation,', 'appelée', 'Linked', 'Extended', 'Regulatory', 'Circuits', '(LERC).', 'TF-gène', 'TF-gène']
# opcodes:  [('equal', 0, 8, 0, 8), ('insert', 8, 8, 8, 10), ('equal', 8, 14, 10, 16), ('delete', 14, 15, 16, 16), ('equal', 15, 16, 16, 17), ('replace', 16, 18, 17, 18)]
# it is ===============================
# index is:  1868
# current tp:  8 total tp:  8
# current tp:  6 total tp:  14
# current tp:  1 total tp:  15
# total tp global:  1612
# words1: ['en', '1', '205', 'graphes', 'nommés', 'RDF']
# words2: []
# opcodes:  [('delete', 0, 6, 0, 0)]
# it is ===============================
# index is:  1869
# total tp global:  1612
# words1: ['3', '910', '794', '050', 'triplets', 'que', 'point', 'de', 'terminaison', 'SPARQL', ':']
# words2: []
# opcodes:  [('delete', 0, 11, 0, 0)]
# it is ===============================
# index is:  1870
# total tp global:  1612
# words1: ['requêtes']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  1871
# total tp global:  1612
# words1: ["d'interroger"]
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  1872
# total tp global:  1612
# words1: ['associé', 'https://regulatorycircuits-lod.genouest.org']
# words2: []
# opcodes:  [('delete', 0, 2, 0, 0)]
# it is ===============================
# index is:  1873
# total tp global:  1612
# words1: ['FAIRification', 'modèle', 'sémantique', 'météorologique']
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  1874
# total tp global:  1612
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  1875
# total tp global:  1612
# words1: []
# words2: ['nécessite']
# opcodes:  [('insert', 0, 0, 0, 1)]
# it is ===============================
# index is:  1876
# total tp global:  1612
# words1: ['de', 'FAIRification', 'des', 'données', 'réutilisabilité.']
# words2: []
# opcodes:  [('delete', 0, 5, 0, 0)]
# it is ===============================
# index is:  1877
# total tp global:  1612
# words1: ['schéma']
# words2: []
# opcodes:  [('delete', 0, 1, 0, 0)]
# it is ===============================
# index is:  1878
# total tp global:  1612
# words1: ['améliore', 'la', 'FAIRness.']
# words2: ['"SYNOP"']
# opcodes:  [('replace', 0, 3, 0, 1)]
# it is ===============================
# index is:  1879
# total tp global:  1612
# words1: ['Expliquer', 'les', 'modèles', "d'apprentissage", 'profond', 'pour', "l'usurpation", 'et', 'la', 'détection', 'de', 'faux', 'avec', 'Shapley', 'Additive', 'Explications']
# words2: ["l'usurpation", 'et', 'de', 'faux']
# opcodes:  [('delete', 0, 6, 0, 0), ('equal', 6, 8, 0, 2), ('delete', 8, 10, 2, 2), ('equal', 10, 12, 2, 4), ('delete', 12, 16, 4, 4)]
# it is ===============================
# index is:  1880
# current tp:  2 total tp:  2
# current tp:  2 total tp:  4
# total tp global:  1616
# words1: ["d'usurpation", 'détection', 'de', 'faux']
# words2: ['de', 'détection', 'de', 'faux']
# opcodes:  [('replace', 0, 1, 0, 1), ('equal', 1, 4, 1, 4)]
# it is ===============================
# index is:  1881
# current tp:  3 total tp:  3
# total tp global:  1619
# words1: ['percée', 'classifieur', 'produit', 'sa', 'production.']
# words2: []
# opcodes:  [('delete', 0, 5, 0, 0)]
# it is ===============================
# index is:  1882
# total tp global:  1619
# words1: ["d'usurpation", 'de', 'boîte', 'noire']
# words2: ['de', 'boîte', 'noire', 'vers']
# opcodes:  [('delete', 0, 1, 0, 0), ('equal', 1, 4, 0, 3), ('insert', 4, 4, 3, 4)]
# it is ===============================
# index is:  1883
# current tp:  3 total tp:  3
# total tp global:  1622
# words1: ['SHapley', 'Additive', 'exPlanations', "d'usurpation."]
# words2: []
# opcodes:  [('delete', 0, 4, 0, 0)]
# it is ===============================
# index is:  1884
# total tp global:  1622
# words1: ['sorties', 'classificateur', "d'usurpation."]
# words2: ['artefacts']
# opcodes:  [('replace', 0, 3, 0, 1)]
# it is ===============================
# index is:  1885
# total tp global:  1622
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  1886
# total tp global:  1622
# words1: []
# words2: []
# opcodes:  []
# it is ===============================
# index is:  1887
# total tp global:  1622
# severity_tp:  {'major': 975, 'minor': 598, 'critical': 49}
# severity_fp:  {'minor': 3313, 'major': 3776, 'critical': 109}

# %%
tp
# Out:
# 1622

# %%
fp
# Out:
# 7198

# %%
fn
# Out:
# 1361

# %% [raw]
# replace

# %%
replace
# Out:
# 1186

# %%
tp = 0
severity_tp = {}

words_in_the_spans = {'minor': ['algorithme', 'grammaires', 'adjacentes', 'à', "l'arbre", 'lexicalisé', '(LTAG)', 'bilexi-cal']}
relevant_words = ['adjacentes', 'à', "l'arbre", 'lexicalisé', 'bilexi-cal']

for severity, words in words_in_the_spans.items():
    # Iterate over a COPY of the list to avoid skipping elements
    for word in words:  # Key fix: `list(words)` creates a snapshot
        print("word: ",word)
        if word in relevant_words:
            tp += 1
            severity_tp[severity] = severity_tp.get(severity, 0) + 1
            # Remove from both lists
            words.remove(word)
            relevant_words.remove(word)

print("After removal:")
print("words_in_the_spans:", words_in_the_spans)
print("relevant_words:", relevant_words)
# Out:
# word:  algorithme
# word:  grammaires
# word:  adjacentes
# word:  l'arbre
# word:  (LTAG)
# word:  bilexi-cal
# After removal:
# words_in_the_spans: {'minor': ['algorithme', 'grammaires', 'à', 'lexicalisé', '(LTAG)']}
# relevant_words: ['à', 'lexicalisé']

# %%
tp = 0
severity_tp = {}

words_in_the_spans = {'minor': ['algorithme', 'grammaires', 'adjacentes', 'à', "l'arbre", 'lexicalisé', '(LTAG)', 'bilexi-cal']}
relevant_words = ['adjacentes', 'à', "l'arbre", 'lexicalisé', 'bilexi-cal']

for severity, words in words_in_the_spans.items():
    # Iterate over a COPY of the list to avoid skipping elements
    for word in list(words):  # Key fix: `list(words)` creates a snapshot
        if word in relevant_words:
            tp += 1
            severity_tp[severity] = severity_tp.get(severity, 0) + 1
            # Remove from both lists
            words.remove(word)
            relevant_words.remove(word)

print("After removal:")
print("words_in_the_spans:", words_in_the_spans)
print("relevant_words:", relevant_words)
# Out:
# After removal:
# words_in_the_spans: {'minor': ['algorithme', 'grammaires', '(LTAG)']}
# relevant_words: []
