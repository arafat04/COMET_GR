# %%
# !pwd
# Out:
# /auto/brno2/brno2/rahmang/xcomet/arafat_comet/COMET_GR/eng_to_czech

# %%
home = "/auto/brno2/brno2/rahmang/"

# %%
import os

# %%
abstract_metadata = "thesis_czech/thesis_codes/abstract_metadata_with_ideal_spans_correct_no_spans_with_min4chars.tsv"

# %%
path = os.path.join(home,abstract_metadata)

# %%
import pandas as pd

df = pd.read_csv(path, sep="\t")

print(df.head())
# Out:
#     hal_id  translation_id                                   sentence_indices  \
# 0  3911658           18797  [1749, 1750, 1751, 1752, 1753, 1754, 1755, 175...
# 1  3946223           10147  [152, 153, 154, 155, 156, 157, 158, 159, 160, ...
# 2  3602177           17469  [1858, 1859, 1860, 1861, 1862, 1863, 1864, 186...
# 3  3636034           11525  [1191, 1192, 1193, 1194, 1195, 1196, 1197, 119...
# 4  3972415           12792  [1537, 1538, 1539, 1540, 1541, 1542, 1543, 154...
#
#    num_sentences  total_characters  \
# 0             20              3318
# 1             26              3308
# 2             16              3162
# 3             15              2892
# 4             13              2845
#
#                                               source  total_spans  \
# 0  An intermestic approach to China's public dipl...            8
# 1  Development of a holistic communication score ...            7
# 2  Improving reusability along the data life cycl...            4
# ...

# %%
# read the df_en_cz_original_with_id_numbers df
import pandas as pd

df = pd.read_csv("./df_en_cz_original_with_id_numbers")

# %%
df.head()
# Out:
#                                                  ref  \
# 0  {'R1': 'Vláda přikázala odchod do důchodu dalš...
# 1  {'R1': 'Ústřední rada nepřímých daní a cel (CB...
# 2  {'R1': 'Od června je to už počtvrté, co jsou z...
# 3  {'R1': 'Podle oficiálních zdrojů proběhla akce...
# 4  {'R1': '„Nedávno jsme podnikli odvážný krok, k...
#
#                                              systems  \
# 0  {'CUNI-DocTransformer.1450': {'score': 0.76862...
# 1  {'CUNI-DocTransformer.1450': {'score': 0.58643...
# 2  {'CUNI-DocTransformer.1450': {'score': 0.63602...
# 3  {'CUNI-DocTransformer.1450': {'score': -0.2728...
# 4  {'CUNI-DocTransformer.1450': {'score': 0.37188...
#
#                                                  src  id_hal  Translation_id  \
# 0  The government has compulsorily retired 15 mor...       1               1
# 1  The Central Board of Indirect Taxes and Custom...       1               1
# 2  Since June, this is the fourth round of sackin...       1               1
# ...

# %%
df_en_cz = pd.read_csv("df_en_cz_final.csv")
df_en_cz.head(16)
# Out:
#     id_hal  Translation_id  line_id  \
# 0        1               1        1
# 1        1               1        2
# 2        1               1        3
# 3        1               1        4
# 4        1               1        5
# 5        1               1        6
# 6        1               1        7
# 7        1               1        8
# 8        2               2        1
# 9        2               2        2
# 10       2               2        3
# 11       2               2        4
# 12       2               2        5
# 13       2               2        6
# 14       2               2        7
# 15       2               2        8
#
#                                                source  \
# 0   The government has compulsorily retired 15 mor...
# 1   The Central Board of Indirect Taxes and Custom...
# 2   Since June, this is the fourth round of sackin...
# 3   Sources said the action was in line with Prime...
# 4   "We have recently taken the bold step of compu...
# ...
