# %%
import pandas as pd
statistics_results_json = "/storage/brno2/home/rahmang/xcomet/arafat_comet/COMET_GR/all_entries.json"
# Read the JSON file into a DataFrame
df_json = pd.read_json(statistics_results_json)

# Optional: Set the 'index' column as the DataFrame index
df_json = df_json.set_index("index")

# Display the DataFrame
print(df_json.head())
# Out:
#                                                   source  \
# index
# 1      Transforming Dependency Structures to LTAG Der...
# 2      We propose a new algorithm for parsing Lexical...
# 3      That is, given a sentence and its correspondin...
# 4      Moreover, we prove that this algorithm has a l...
# 5      This algorithm returns all compatible derivati...
#
#                                              translation  \
# index
# 1      Transformation de structures de dépendances en...
# 2      Nous proposons un nouvel algorithme pour analy...
# 3      C'est-à-dire, compte tenu d'une phrase et de s...
# 4      Par ailleurs, on prouve que cet algorithme pré...
# 5      Cet algorithme retourne tous les arbres de dér...
#
#                                              postedition  \
# index
# 1      Transformation de structures de dépendances en...
# 2      Nous proposons un nouvel algorithme pour analy...
# 3      C'est-à-dire, étant donné une phrase et de sa ...
# ...

# %%
# Temporarily adjust display settings
with pd.option_context(
    "display.max_columns", None,  # Show all columns
    "display.max_colwidth", None,  # Show full content of cells
    "display.width", None,  # Auto-detect terminal width
    #"display.max_rows", None  # Show all rows (optional)
):
    print(df_json)
# Out:
#                                                                                                                                                                                                                                                source  \
# index
# 1                                                                                                                                                                                         Transforming Dependency Structures to LTAG Derivation Trees
# 2                                                                                             We propose a new algorithm for parsing Lexicalized Tree Adjoining Grammars (LTAGs) which uses pre-assigned bilexi-cal dependency relations as a filter.
# ...
